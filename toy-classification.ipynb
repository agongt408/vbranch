# %%
from sklearn.datasets import make_classification, make_blobs
import numpy as np
import matplotlib.pyplot as plt

# %%
np.log2(8) % 1 == 0
# Out:
# True

# %%
X, y = make_classification(n_features=2, n_informative=2, n_redundant=0,
                           n_classes=3, n_clusters_per_class=1, class_sep=4,
                           random_state=100, shuffle=False)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.jet)
plt.colorbar()
plt.show()

# %%
X
# Out:
# array([[ 5.78873817, -3.80152316],
#        [ 4.01140791, -4.02987613],
#        [ 4.05071922, -4.08601786],
#        [ 4.62953141, -3.7977325 ],
#        [ 4.42550038, -3.95394468],
#        [ 4.80795989, -3.53074909],
#        [ 4.17199999, -4.03060141],
#        [ 4.20159749, -3.7575934 ],
#        [ 4.21315899, -3.88352234],
#        [ 5.29317519, -3.84711259],
#        [ 4.80889822, -3.94375695],
#        [ 3.30118896, -4.18303147],
#        [ 2.20280944, -4.18471565],
#        [ 4.60556524, -4.15128662],
#        [ 4.52557112, -4.18535471],
#        [ 2.38432546, -4.41825149],
#        [ 4.28364868, -3.89104007],
#        [ 3.98896923, -3.93965689],
#        [ 4.1774981 , -4.01539419],
#        [ 3.98966543, -3.90745203],
#        [ 3.8446983 , -3.79153101],
#        [ 4.74319441, -3.93214833],
#        [ 4.14747503, -4.02396501],
#        [ 4.91563075, -3.93770241],
#        [ 4.1840433 , -3.94199122],
#        [ 4.55455458, -3.90818412],
#        [ 3.86903792, -3.89342873],
#        [ 3.43541821, -3.99272674],
#        [ 5.34727108, -3.84448296],
#        [ 4.03547771, -3.99152638],
#        [ 4.22531671, -3.92761482],
#        [ 3.25367285, -4.29364426],
#        [ 4.73689773, -3.96664143],
#        [ 4.09290503, -4.01711496],
#        [-4.38649024,  3.26851283],
#        [-2.84184974,  7.13313538],
#        [-3.63664458,  4.45309148],
#        [-3.63048796,  5.05266117],
#        [-3.84319555,  3.79909914],
#        [-4.13838731,  3.56901898],
#        [-4.60777271,  2.89877572],
#        [-3.81151362,  4.97484237],
#        [-3.66566782,  4.68722646],
#        [-4.02129798,  3.87523495],
#        [-3.70825962,  4.43757674],
#        [-3.87872923,  5.24876418],
#        [-3.50643437,  5.54360904],
#        [-4.23954346,  4.13716837],
#        [-3.56580679,  5.6095279 ],
#        [-4.48699087,  3.27829796],
#        [-4.99269318,  1.81599002],
#        [-5.42193282,  1.34926969],
#        [-4.22741933,  2.80899636],
#        [-4.79933086,  2.52464537],
#        [-4.06688746,  4.34676583],
#        [-3.81644483,  4.54682468],
#        [-4.21194967,  3.61850157],
#        [-3.48000382,  5.93066368],
#        [-3.14904161,  5.55662658],
#        [-4.34743468,  2.97582361],
#        [-3.45014715,  5.77956837],
#        [-2.84934098,  6.19256153],
#        [-4.24316727,  3.83643539],
#        [-4.04912891,  4.43302765],
#        [-4.16144073,  3.24184066],
#        [-4.20189732,  3.6224243 ],
#        [-4.20738531,  2.9690923 ],
#        [ 3.60492956,  3.98723861],
#        [ 4.52166588,  3.96439226],
#        [ 3.82446519,  4.31222346],
#        [ 4.68858687,  3.92619083],
#        [ 4.87691334,  4.16992813],
#        [ 4.60833503,  3.97119046],
#        [ 3.78957422,  3.97486591],
#        [ 4.08080555,  4.0545894 ],
#        [ 3.8985746 ,  4.16360541],
#        [ 3.91748448,  4.1325313 ],
#        [ 4.44574417,  4.21632799],
#        [ 3.91645344,  4.17325655],
#        [ 4.23935473,  3.91657746],
#        [ 4.02135587,  4.04826854],
#        [ 3.78818492,  4.06472516],
#        [ 3.60631842,  4.21899132],
#        [ 3.36423514,  3.94074218],
#        [ 4.71700191,  4.18701066],
#        [ 4.12237276,  4.06558379],
#        [ 4.39219714,  3.93330094],
#        [ 4.18953809,  3.87266265],
#        [ 4.04037838,  4.05133242],
#        [ 3.59403943,  3.97928827],
#        [ 4.06676434,  3.85552313],
#        [ 4.08820233,  4.23310868],
#        [ 3.82358513,  4.04124688],
#        [ 3.67667574,  4.03871522],
#        [ 4.16713963,  4.04586258],
#        [ 3.62620251,  4.10890338],
#        [ 4.15814134,  4.1164076 ],
#        [ 4.02860839,  3.86527493],
#        [ 3.66612489,  3.82200586],
#        [ 3.78255293,  3.92806011]])

# %%
X, y = make_blobs(n_samples=[25]*20, n_features=2)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.jet)
plt.colorbar()
plt.show()
